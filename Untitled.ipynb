# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'test_8i3B3FC.csv')

# %%
df
# Out:
#             ID Tag  Reputation  Answers  Username    Views
# 0       366953   a      5645.0      3.0     50652  33200.0
# 1        71864   c     24511.0      6.0     37685   2730.0
# 2       141692   i       927.0      1.0    135293  21167.0
# 3       316833   i        21.0      6.0    166998  18528.0
# 4       440445   i      4475.0     10.0     53504  57240.0
# ...        ...  ..         ...      ...       ...      ...
# 141443   47187   j      4681.0      4.0    152060   2469.0
# 141444  329126   j      7782.0      3.0     89235  18998.0
# 141445  282334   p       435.0      5.0    119788  57048.0
# 141446  386629   o       176.0      3.0     86824  10193.0
# 141447  107271   a       648.0      2.0    102240  12785.0
#
# [141448 rows x 6 columns]

# %%
df.shape
# Out:
# (141448, 6)

# %%
df.size
# Out:
# 848688

# %%
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views
# 0  366953   a      5645.0      3.0     50652  33200.0
# 1   71864   c     24511.0      6.0     37685   2730.0
# 2  141692   i       927.0      1.0    135293  21167.0
# 3  316833   i        21.0      6.0    166998  18528.0
# 4  440445   i      4475.0     10.0     53504  57240.0

# %%
df.tail()
# Out:
#             ID Tag  Reputation  Answers  Username    Views
# 141443   47187   j      4681.0      4.0    152060   2469.0
# 141444  329126   j      7782.0      3.0     89235  18998.0
# 141445  282334   p       435.0      5.0    119788  57048.0
# 141446  386629   o       176.0      3.0     86824  10193.0
# 141447  107271   a       648.0      2.0    102240  12785.0

# %%
df.isnull().sum()
# Out:
# ID            0
# Tag           0
# Reputation    0
# Answers       0
# Username      0
# Views         0
# dtype: int64

# %%
cat = df.select_dtypes(include=['object']).columns
num= df.select_dtypes(exclude=['object']).columns

print('CAT:',cat)
print('NUM:',num)
# Out:
# CAT: Index(['Tag'], dtype='object')
# NUM: Index(['ID', 'Reputation', 'Answers', 'Username', 'Views'], dtype='object')

# %%
df[cat].value_counts()
# Out:
# Tag
# j      30811
# c      30793
# p      18713
# i      14100
# a      13558
# s      10088
# h       8782
# o       6296
# r       5313
# x       2994
# Name: count, dtype: int64

# %%
df['Tag'].unique()
# Out:
# array(['a', 'c', 'i', 'x', 's', 'p', 'o', 'j', 'h', 'r'], dtype=object)

# %%
df['Tag'].nunique()
# Out:
# 10

# %%
for i in num:
    a=df[num].nunique()
    
    print(i,a)
    break
# Out:
# ID ID            141448
# Reputation     14098
# Answers           58
# Username       79351
# Views          52807
# dtype: int64

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
plt.show()

# %%
df.describe()
# Out:
#                   ID    Reputation        Answers       Username         Views
# count  141448.000000  1.414480e+05  141448.000000  141448.000000  1.414480e+05
# mean   235743.073497  7.920927e+03       3.914873   81348.231117  2.984633e+04
# std    136269.867118  2.791072e+04       3.577460   49046.098215  8.034374e+04
# min         7.000000  0.000000e+00       0.000000       4.000000  9.000000e+00
# 25%    117797.000000  2.860000e+02       2.000000   40222.750000  2.608000e+03
# 50%    235830.000000  1.245000e+03       3.000000   78795.500000  8.977000e+03
# 75%    353616.000000  5.123000e+03       5.000000  122149.000000  2.698925e+04
# max    471488.000000  1.042428e+06      73.000000  175737.000000  5.004669e+06

# %%
for i in num:
    sns.distplot(df[i])
    plt.show()

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total number of plots (rows * columns)
total_plots = 10 * 2

# Create a figure and axes for the subplots
fig, axes = plt.subplots(10, 2, figsize=(15, 30))  # 5 rows, 4 columns - Adjust the figsize as needed

# Your existing code with minor modifications
plot_counter = 0  # Initialize a counter for subplot positions

for i in num:
    for j in num:
        if i != j and plot_counter < total_plots:  # Check if plot_counter exceeds total_plots
            ax = axes[plot_counter // 2, plot_counter % 2]  # Get the current subplot
            ax.scatter(df[i], df[j])
            ax.set_title(f'Columns: {i} vs {j}')
            plot_counter += 1  # Increment the plot counter

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
for i in (num):
    print(i,df[i].skew())
# Out:
# ID 0.0006927946927167146
# Reputation 11.318535544194582
# Answers 3.3980912343127145
# Username 0.14744775131758642
# Views 13.532848265572564

# %%
df['Reputation'] = np.log1p(df['Reputation'])

# %%
df['Reputation'].skew()
# Out:
# -0.5199467492448395

# %%
df['Answers'] = np.log1p(df['Answers'])

# %%
df['Answers'].skew()
# Out:
# 0.5301850603105368

# %%
df['Views'] = np.log1p(df['Views'])

# %%
df['Views'].skew()
# Out:
# -0.3397425022935254

# %%
for i in (num):
    print(i,df[i].skew())
# Out:
# ID 0.0006927946927167146
# Reputation -0.5199467492448395
# Answers 0.5301850603105368
# Username 0.14744775131758642
# Views -0.3397425022935254

# %%
for i in num:
    sns.distplot(df[i])
    plt.show()

# %%
num
# Out:
# Index(['ID', 'Reputation', 'Answers', 'Username', 'Views'], dtype='object')

# %%
num1=['Reputation', 'Answers', 'Username', 'Views']

# %%
from sklearn.preprocessing import MinMaxScaler
me=MinMaxScaler()
df[num1]=me.fit_transform(df[num1])

# %%
df
# Out:
#             ID Tag  Reputation   Answers  Username     Views
# 0       366953   a    0.623415  0.322090  0.288210  0.617814
# 1        71864   c    0.729369  0.452110  0.214422  0.427472
# 2       141692   i    0.493108  0.161045  0.769855  0.583517
# 3       316833   i    0.223066  0.452110  0.950271  0.573370
# 4       440445   i    0.606657  0.557123  0.304439  0.659319
# ...        ...  ..         ...       ...       ...       ...
# 141443   47187   j    0.609904  0.373934  0.865267  0.419817
# 141444  329126   j    0.646580  0.322090  0.507765  0.575279
# 141445  282334   p    0.438595  0.416295  0.681625  0.659063
# 141446  386629   o    0.373539  0.322090  0.494045  0.527838
# 141447  107271   a    0.467302  0.255250  0.581769  0.545101
#
# [141448 rows x 6 columns]

# %%
df1=df['ID']

# %%
df1=pd.DataFrame(df1)
df1
# Out:
#             ID
# 0       366953
# 1        71864
# 2       141692
# 3       316833
# 4       440445
# ...        ...
# 141443   47187
# 141444  329126
# 141445  282334
# 141446  386629
# 141447  107271
#
# [141448 rows x 1 columns]

# %%
# df=df.drop('ID',axis=1)

# %%
df
# Out:
#             ID Tag  Reputation   Answers  Username     Views
# 0       366953   a    0.623415  0.322090  0.288210  0.617814
# 1        71864   c    0.729369  0.452110  0.214422  0.427472
# 2       141692   i    0.493108  0.161045  0.769855  0.583517
# 3       316833   i    0.223066  0.452110  0.950271  0.573370
# 4       440445   i    0.606657  0.557123  0.304439  0.659319
# ...        ...  ..         ...       ...       ...       ...
# 141443   47187   j    0.609904  0.373934  0.865267  0.419817
# 141444  329126   j    0.646580  0.322090  0.507765  0.575279
# 141445  282334   p    0.438595  0.416295  0.681625  0.659063
# 141446  386629   o    0.373539  0.322090  0.494045  0.527838
# 141447  107271   a    0.467302  0.255250  0.581769  0.545101
#
# [141448 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Tag']=le.fit_transform(df['Tag'])

# %%
df
# Out:
#             ID  Tag  Reputation   Answers  Username     Views
# 0       366953    0    0.623415  0.322090  0.288210  0.617814
# 1        71864    1    0.729369  0.452110  0.214422  0.427472
# 2       141692    3    0.493108  0.161045  0.769855  0.583517
# 3       316833    3    0.223066  0.452110  0.950271  0.573370
# 4       440445    3    0.606657  0.557123  0.304439  0.659319
# ...        ...  ...         ...       ...       ...       ...
# 141443   47187    4    0.609904  0.373934  0.865267  0.419817
# 141444  329126    4    0.646580  0.322090  0.507765  0.575279
# 141445  282334    6    0.438595  0.416295  0.681625  0.659063
# 141446  386629    5    0.373539  0.322090  0.494045  0.527838
# 141447  107271    0    0.467302  0.255250  0.581769  0.545101
#
# [141448 rows x 6 columns]

# %%
import pickle
rf=pickle.load(open("best_model.pkl",'rb'))

# %%
y_pred=rf.predict(df)

# %%
pred_df=pd.DataFrame(y_pred,columns=['Upvotes'])

# %%
pred_df
# Out:
#          Upvotes
# 0       0.412558
# 1       0.309925
# 2       0.255609
# 3       0.189704
# 4       0.435728
# ...          ...
# 141443  0.241518
# 141444  0.390373
# 141445  0.280775
# 141446  0.167509
# 141447  0.225673
#
# [141448 rows x 1 columns]

# %%
df2=pd.concat([df1,pred_df],axis=1)

# %%
df2
# Out:
#             ID   Upvotes
# 0       366953  0.412558
# 1        71864  0.309925
# 2       141692  0.255609
# 3       316833  0.189704
# 4       440445  0.435728
# ...        ...       ...
# 141443   47187  0.241518
# 141444  329126  0.390373
# 141445  282334  0.280775
# 141446  386629  0.167509
# 141447  107271  0.225673
#
# [141448 rows x 2 columns]

# %%
df2=df2.set_index('ID')

# %%
df2
# Out:
#          Upvotes
# ID
# 366953  0.412558
# 71864   0.309925
# 141692  0.255609
# 316833  0.189704
# 440445  0.435728
# ...          ...
# 47187   0.241518
# 329126  0.390373
# 282334  0.280775
# 386629  0.167509
# 107271  0.225673
#
# [141448 rows x 1 columns]

# %%
df2.to_csv('model3.csv')
